# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_6_features'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_3_features'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_merged'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    df2['para'] = df2['para'].replace({
        "DL_early-0-0-0": "DL_early_ppi-0-0-0",
        "DL_mid-0-0-0": "DL_mid_ppi-0-0-0",
        "DL_later_avg-0-0-0": "DL_later_avg_ppi-0-0-0",
        "DL_later_mlp-0-0-0": "DL_later_mlp_ppi-0-0-0"
    })

    df2 = df2[df2['para'] != 'DL_string_id-0-0-0']
    df1 = df1[df1['para'] != 'DL_string_id-0-0-0']


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_oob'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_oob_ppi'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_nn_oob_all'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    df2['para'] = df2['para'].replace({
        "DL_early-0-0-0": "DL_early_ppi-0-0-0",
        "DL_mid-0-0-0": "DL_mid_ppi-0-0-0",
        "DL_later_avg-0-0-0": "DL_later_avg_ppi-0-0-0",
        "DL_later_mlp-0-0-0": "DL_later_mlp_ppi-0-0-0"
    })

    df2 = df2[df2['para'] != 'DL_string_id-0-0-0']
    df1 = df1[df1['para'] != 'DL_string_id-0-0-0']


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/df_early'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/df_early_ppi'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/df_early_all'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    df1['para'] = df1['para'].replace({"df_early-0-0-0": "early_fused-0-0-0"})
    df2['para'] = df2['para'].replace({"df_early_ppi-0-0-0": "early_fused_ppi-0-0-0"})

    # df2 = df2[df2['para'] != 'DL_string_id-0-0-0']
    # df1 = df1[df1['para'] != 'DL_string_id-0-0-0']


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/df_early_all'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    # df1['para'] = df1['para'].replace({"df_early-0-0-0": "early_fused-0-0-0"})
    # df2['para'] = df2['para'].replace({"df_early_ppi-0-0-0": "early_fused_ppi-0-0-0"})

    # df2 = df2[df2['para'] != 'DL_string_id-0-0-0']
    # df1 = df1[df1['para'] != 'DL_string_id-0-0-0']


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd
root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_occ_deep_svd'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_occ_val_unlabled'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_occ_all'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)

    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_test_pos_to_neg_mid'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_test_pos_to_neg_ppi_mid'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_correct_mid'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    df2['para'] = df2['para'].replace({
        "linear_fused-0-0-0": "linear_fused_ppi-0-0-0",
        "geo_fused-0-0-0": "geo_fused_ppi-0-0-0"
    })


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # df3 = df3[df3['para'] != 'DL_mid-0-0-0']
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob_mid'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob_ppi_mid'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    df2['para'] = df2['para'].replace({
        "linear_fused-0-0-0": "linear_fused_ppi-0-0-0",
        "geo_fused-0-0-0": "geo_fused_ppi-0-0-0"
    })


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # df3 = df3[df3['para'] != 'DL_mid-0-0-0']
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob_lf'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_df_oob'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    # df2['para'] = df2['para'].replace({
    #     "linear_fused-0-0-0": "linear_fused_ppi-0-0-0",
    #     "geo_fused-0-0-0": "geo_fused_ppi-0-0-0"
    # })


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # df3 = df3[df3['para'] != 'DL_mid-0-0-0']
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_gnn_improved'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_gnn_improved_sage'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_gnn'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root1):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    # df2['para'] = df2['para'].replace({
    #     "linear_fused-0-0-0": "linear_fused_ppi-0-0-0",
    #     "geo_fused-0-0-0": "geo_fused_ppi-0-0-0"
    # })


    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # df3 = df3[df3['para'] != 'DL_mid-0-0-0']
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
df3
# Out:
#              method  fold                    para  top_recall_25  \
# 0   random_negative     1  uniport_ppi_2019-0-0-0         0.1579
# 1   random_negative     1    ppi_2019_dw_40-0-0-0         0.2105
# 2   random_negative     1    diffusion_2019-0-0-0         0.2105
# 3   random_negative     1       uniport_bio-0-0-0         0.0526
# 4   random_negative     1       uniport_seq-0-0-0         0.0526
# 5   random_negative     1       uniport_esm-0-0-0         0.0000
# 6   random_negative     1      linear_fused-0-0-0         0.1579
# 7   random_negative     1         geo_fused-0-0-0         0.1053
# 11  random_negative     1  linear_fused_ppi-0-0-0         0.2105
# 12  random_negative     1     geo_fused_ppi-0-0-0         0.2632
#
#     top_recall_300  top_recall_10%  top_precision_10%  max_precision_10%  \
# 0           0.4211          0.6842             0.0084             0.0123
# 1           0.5263          0.6842             0.0084             0.0123
# 2           0.4737          0.6842             0.0084             0.0123
# 3           0.2632          0.5263             0.0064             0.0123
# 4           0.1053          0.4737             0.0058             0.0123
# 5           0.0526          0.4737             0.0058             0.0123
# 6           0.5263          0.6842             0.0084             0.0123
# 7           0.5263          0.6842             0.0084             0.0123
# 11          0.4737          0.6842             0.0084             0.0123
# 12          0.5789          0.6842             0.0084             0.0123
#
#     top_recall_30%  top_precision_30%  ...  pm_15%  pm_20%  pm_25%  pm_30%  \
# 0           0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 1           0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 2           0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 3           0.7368             0.0030  ...  0.8087  0.7744  0.7328  0.7110
# 4           0.7368             0.0030  ...  0.7787  0.7437  0.7471  0.7110
# 5           0.6842             0.0028  ...  0.7787  0.7437  0.7328  0.6955
# 6           0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 7           0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 11          0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
# 12          0.6842             0.0028  ...  0.8208  0.7744  0.7328  0.6955
#
#      auroc  rank_ratio  bedroc_1  bedroc_5  bedroc_10  bedroc_30
# 0   0.7334      0.2669    0.3089    0.4917     0.5648     0.6420
# 1   0.7653      0.2351    0.3431    0.5340     0.5977     0.6615
# 2   0.7919      0.2085    0.3219    0.5014     0.5751     0.6574
# 3   0.7459      0.2545    0.0990    0.2816     0.3882     0.5571
# 4   0.7683      0.2321    0.0551    0.1811     0.2871     0.5000
# 5   0.7325      0.2678    0.0217    0.1543     0.2632     0.4698
# 6   0.7664      0.2339    0.3405    0.5218     0.5868     0.6590
# 7   0.7844      0.2159    0.2983    0.5032     0.5742     0.6568
# 11  0.7422      0.2582    0.3340    0.5185     0.5857     0.6514
# 12  0.7703      0.2300    0.3715    0.5444     0.6026     0.6681
#
# [10 rows x 25 columns]

# %%
import os
import pandas as pd

root1 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_rf'
root2 = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_rf_after10_early'
out_folder = '/itf-fi-ml/shared/users/ziyuzh/svm/results/2019_rf_all'

# Ensure output dir exists
os.makedirs(out_folder, exist_ok=True)

for file_name in os.listdir(root2):
    if 'all' in file_name:
        continue

    file_path1 = os.path.join(root1, file_name)
    file_path2 = os.path.join(root2, file_name)

    # Skip if the counterpart is missing in root2
    if not os.path.isfile(file_path1) or not os.path.isfile(file_path2):
        continue

    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)

    # Round all numeric columns to 4 decimals
    df1 = df1.copy()
    df2 = df2.copy()
    num_cols1 = df1.select_dtypes(include='number').columns
    num_cols2 = df2.select_dtypes(include='number').columns
    df1[num_cols1] = df1[num_cols1].round(4)
    df2[num_cols2] = df2[num_cols2].round(4)

    # Merge row by row (concatenate) and de-duplicate rows
    df3 = pd.concat([df1, df2], ignore_index=True, sort=False).drop_duplicates()
    # df3 = df3[df3['para'] != 'DL_mid-0-0-0']
    # Save
    out_path = os.path.join(out_folder, file_name)
    df3.to_csv(out_path, index=False)

# %%
for file_name in os.listdir(out_folder):
    if 'all' in file_name:
        continue
    file_path = os.path.join(out_folder, file_name)
    df = pd.read_csv(file_path)

    if 'RF_later_mlp' in df['para']:
        print(file_name)
